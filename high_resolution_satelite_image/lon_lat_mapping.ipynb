# %%
import os
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame as gdf
from random import randint
import plotly.express as px

# %% [markdown]
# - https://stackoverflow.com/questions/58043978/display-data-on-real-map-based-on-postal-code
# - https://www12.statcan.gc.ca/census-recensement/2011/geo/bound-limit/bound-limit-2011-eng.cfm
# - https://stackoverflow.com/questions/53233228/plot-latitude-longitude-from-csv-in-python-3-6
# - https://docs.mapbox.com/playground/static/
# - https://towardsdatascience.com/scatter-plots-on-maps-using-plotly-79f16aee17d0
# - https://plotly.com/python/mapbox-layers/

# %% [markdown]
# #### First, Import and process the dataset. Then, Follow the next steps

# %%
  # World map by geo pandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(30, 10)), marker='o', color='red', markersize=15);

# %%
colors = []
for i in range(len(df)):
    colors.append('#%06X' % randint(0, 0xFFFFFF))

# %%
px.set_mapbox_access_token("from random import randint")

fig = px.scatter_mapbox(
    df,
    lat="Latitude",
    lon="Longitude",
    # custom_data='IESO',
    color="IESO",
    color_continuous_scale=px.colors.cyclical.IceFire,
    size_max=20,
    zoom=12,
    mapbox_style="satellite",
)
fig.update_layout(
    autosize=False,
    width=1500,
    height=800,
)

fig.show()
